# %%
import pandas as pd

# %%
series=pd.Series(["Gracy", "Simran", "Tanishka", "Shreya"])
series
# Out:
# 0       Gracy
# 1      Simran
# 2    Tanishka
# 3      Shreya
# dtype: object

# %%
boys=pd.Series(["Devender", "Bhupender", "Prakhar", "Tanishk"])
boys
# Out:
# 0     Devender
# 1    Bhupender
# 2      Prakhar
# 3      Tanishk
# dtype: object

# %%
tb=pd.DataFrame({"girls":series, "boys":boys})
tb
# Out:
#       girls       boys
# 0     Gracy   Devender
# 1    Simran  Bhupender
# 2  Tanishka    Prakhar
# 3    Shreya    Tanishk

# %%
scrapping=pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
scrapping[1]
# Out:
#                   Date  Added                                Removed  \
#                   Date Ticker                       Security  Ticker
# 0    December 18, 2023   UBER                           Uber     SEE
# 1    December 18, 2023    JBL                          Jabil     ALK
# 2    December 18, 2023   BLDR           Builders FirstSource    SEDG
# 3     October 18, 2023   HUBB                        Hubbell     OGN
# 4     October 18, 2023   LULU            Lululemon Athletica    ATVI
# ..                 ...    ...                            ...     ...
# 333       June 9, 1999    WLP                      Wellpoint     HPH
# 334  December 11, 1998    FSR                        Firstar     LDW
# 335  December 11, 1998    CCL                 Carnival Corp.     GRN
# 336  December 11, 1998   CPWR                      Compuware     SUN
# 337      June 17, 1997    CCI  Countrywide Credit Industries     USL
#
#                                \
#                      Security
# ...

# %%
tb=pd.read_csv(r"C:\Users\Lucky Prem\Downloads\organizations-100\organizations-100.csv")
tb
# Out:
#     Index  Organization Id                     Name  \
# 0       1  FAB0d41d5b5d22c              Ferrell LLC
# 1       2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1               Hester Ltd
# 3       4  2bFC1Be8a4ce42f           Holder-Sellers
# 4       5  9eE8A6a4Eb96C24              Mayer Group
# ..    ...              ...                      ...
# 95     96  0a0bfFbBbB8eC7c             Holmes Group
# 96     97  BA6Cd9Dae2Efd62                 Good Ltd
# 97     98  E7df80C60Abd7f9        Clements-Espinoza
# 98     99  AFc285dbE2fEd24               Mendez Inc
# 99    100  e9eB5A60Cef8354           Watkins-Kaiser
#
#                            Website                      Country  \
# 0               https://price.net/             Papua New Guinea
# 1   http://www.hall-buchanan.info/                      Finland
# 2        http://sullivan-reed.com/                        China
# 3              https://becker.com/                 Turkmenistan
# ...

# %%
#attribute; just provides some meta data about our data
tb.dtypes
# Out:
# Index                   int64
# Organization Id        object
# Name                   object
# Website                object
# Country                object
# Description            object
# Founded                 int64
# Industry               object
# Number of employees     int64
# dtype: object

# %%
from IPython.display import Image
Image(filename="C:\\Users\\Lucky Prem\\Downloads\\WhatsApp Image 2025-01-09 at 10.30.26 PM.jpeg", width=400, height=200)

# %%
tb.columns
# Out:
# Index(['Index', 'Organization Id', 'Name', 'Website', 'Country', 'Description',
#        'Founded', 'Industry', 'Number of employees'],
#       dtype='object')

# %%
len(tb.columns)
len(tb)
tb.shape
# Out:
# (100, 9)

# %%
#functions; used to do some things with the data or perform steps
tb.head()
tb.tail(3)
# Out:
#     Index  Organization Id               Name                  Website  \
# 97     98  E7df80C60Abd7f9  Clements-Espinoza  http://www.flowers.net/
# 98     99  AFc285dbE2fEd24         Mendez Inc   https://www.burke.net/
# 99    100  e9eB5A60Cef8354     Watkins-Kaiser  http://www.herring.com/
#
#                         Country                      Description  Founded  \
# 97  Falkland Islands (Malvinas)          Progressive modular hub     1991
# 98              Kyrgyz Republic  User-friendly exuding migration     1993
# 99                         Togo    Synergistic background access     2009
#
#                 Industry  Number of employees
# 97       Broadcast Media                  236
# 98  Education Management                  339
# 99    Financial Services                 2785

# %%
tb.describe()
tb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Index                100 non-null    int64
#  1   Organization Id      100 non-null    object
#  2   Name                 100 non-null    object
#  3   Website              100 non-null    object
#  4   Country              100 non-null    object
#  5   Description          100 non-null    object
#  6   Founded              100 non-null    int64
#  7   Industry             100 non-null    object
#  8   Number of employees  100 non-null    int64
# dtypes: int64(3), object(6)
# memory usage: 7.2+ KB

# %%
tb.sum()
tb['Number of employees'].sum()
tb['Number of employees'].mean()
# Out:
# 4964.86

# %% [markdown]
# # viewing and selecting/slicing data

# %%
tb.sample(5)
# Out:
#     Index  Organization Id             Name                         Website  \
# 0       1  FAB0d41d5b5d22c      Ferrell LLC              https://price.net/
# 8       9  0B4F93aA06ED03e         Carr Inc                http://ross.com/
# 17     18  5c2EffEfdba2BdF  Mckenzie-Melton    http://montoya-thompson.com/
# 15     16  b5D10A14f7a8AfE      Hodge-Ayers  http://www.archer-elliott.com/
# 2       3  0bFED1ADAE4bcC1       Hester Ltd       http://sullivan-reed.com/
#
#              Country                             Description  Founded  \
# 0   Papua New Guinea     Horizontal empowering knowledgebase     1990
# 8             Kuwait  Distributed impactful customer loyalty     1996
# 17         Hong Kong   Reverse-engineered heuristic alliance     1998
# 15          Honduras   Future-proofed radical implementation     1990
# 2              China          Switchable scalable moratorium     1971
#
#                                              Industry  Number of employees
# ...

# %%
tb.iloc[5:8,2:] #inside/integer location refers to position(for both rows and columns) whereas loc refers to index
# Out:
#              Name                  Website                            Country  \
# 5  Henry-Thompson        http://morse.net/                            Bahamas
# 6  Hansen-Everett    https://www.kidd.org/                           Pakistan
# 7   Mcintosh-Mora  https://www.brooks.com/  Heard Island and McDonald Islands
#
#                                     Description  Founded  \
# 5  Face-to-face well-modulated customer loyalty     1992
# 6        Seamless disintermediate collaboration     2018
# 7      Centralized attitude-oriented capability     1970
#
#                         Industry  Number of employees
# 5  Primary / Secondary Education                 4914
# 6            Publishing Industry                 7832
# 7                Import / Export                 4389

# %%
tb.iloc[[1,3],[1,3]]
# Out:
#    Organization Id                         Website
# 1  6A7EdDEA9FaDC52  http://www.hall-buchanan.info/
# 3  2bFC1Be8a4ce42f             https://becker.com/

# %%
tb.loc[[1,3],['Organization Id', 'Website']]
# Out:
#    Organization Id                         Website
# 1  6A7EdDEA9FaDC52  http://www.hall-buchanan.info/
# 3  2bFC1Be8a4ce42f             https://becker.com/

# %%
tb.loc[5:8,:"Industry"] # lock/location refers to exact index & goes upto that location #.loc requires column labels(e.g., column names like "col_1") rather than positional indices
# Out:
#    Index  Organization Id            Name                  Website  \
# 5      6  cC757116fe1C085  Henry-Thompson        http://morse.net/
# 6      7  219233e8aFF1BC3  Hansen-Everett    https://www.kidd.org/
# 7      8  ccc93DCF81a31CD   Mcintosh-Mora  https://www.brooks.com/
# 8      9  0B4F93aA06ED03e        Carr Inc         http://ross.com/
#
#                              Country  \
# 5                            Bahamas
# 6                           Pakistan
# 7  Heard Island and McDonald Islands
# 8                             Kuwait
#
#                                     Description  Founded  \
# 5  Face-to-face well-modulated customer loyalty     1992
# 6        Seamless disintermediate collaboration     2018
# 7      Centralized attitude-oriented capability     1970
# 8        Distributed impactful customer loyalty     1996
#
#                         Industry
# 5  Primary / Secondary Education
# 6            Publishing Industry
# 7                Import / Export
# ...

# %%
#By default, the delimiter is a comma (,)
pd.read_csv(r"C:/Users/Lucky Prem/Downloads/organizations-100/organizations-100.csv", delimiter=";")

# %%
tb1=pd.read_excel(r"C:\Users\Lucky Prem\Downloads\Online Retail Data Set.xlsx")
tb1

# %%
tb2=pd.read_excel(r"C:\Users\Lucky Prem\Downloads\sample_-_superstore.xls")
tb2=pd.read_excel(r"C:\Users\Lucky Prem\Downloads\sample_-_superstore.xls",sheet_name="People")
tb2
# Out:
#               Person   Region Sex  Age
# 0      Anna Andreadi     West   M   33
# 1        Chuck Magee     East   M   45
# 2     Kelly Williams  Central   F   33
# 3  Cassandra Brandow    South   F   55

# %%
tb2.to_csv(r"C:\Users\Lucky Prem\Downloads\final_tb", index=False) #False to avoid adding index as new column in the final_tb

# %%
tb.to_json(r"C:\Users\Lucky Prem\Downloads\samplejson") #dictionary type

# %%
tb3=pd.read_json(r"C:\Users\Lucky Prem\Downloads\samplejson")
tb3
# Out:
#     Index  Organization Id                            Name  \
# 0       1  FAB0d41d5b5d22c                     Ferrell LLC
# 1       2  6A7EdDEA9FaDC52         Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1                      Hester Ltd
# 3       4  2bFC1Be8a4ce42f                  Holder-Sellers
# 4       5  9eE8A6a4Eb96C24                     Mayer Group
# 5       6  cC757116fe1C085                  Henry-Thompson
# 6       7  219233e8aFF1BC3                  Hansen-Everett
# 7       8  ccc93DCF81a31CD                   Mcintosh-Mora
# 8       9  0B4F93aA06ED03e                        Carr Inc
# 9      10  738b5aDe6B1C6A5                      Gaines Inc
# 10     11  AE61b8Ffebbc476                      Kidd Group
# 11     12  eb3B7D06cCdD609                    Crane-Clarke
# ..    ...              ...                             ...
# 88     89  ED889CB2FE9cbd3                  Huang and Sons
# 89     90  F4Dc1417BC6cb8f                   Gilbert-Simon
# ...

# %%
pd.set_option('display.max.rows', 10) # Show a maximum of 50 rows
pd.set_option('display.max.columns', None) #Display all columns
#pd.reset_option('all')

# %%
tb3
# Out:
#     Index  Organization Id                     Name  \
# 0       1  FAB0d41d5b5d22c              Ferrell LLC
# 1       2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1               Hester Ltd
# 3       4  2bFC1Be8a4ce42f           Holder-Sellers
# 4       5  9eE8A6a4Eb96C24              Mayer Group
# ..    ...              ...                      ...
# 95     96  0a0bfFbBbB8eC7c             Holmes Group
# 96     97  BA6Cd9Dae2Efd62                 Good Ltd
# 97     98  E7df80C60Abd7f9        Clements-Espinoza
# 98     99  AFc285dbE2fEd24               Mendez Inc
# 99    100  e9eB5A60Cef8354           Watkins-Kaiser
#
#                            Website                      Country  \
# 0               https://price.net/             Papua New Guinea
# 1   http://www.hall-buchanan.info/                      Finland
# 2        http://sullivan-reed.com/                        China
# 3              https://becker.com/                 Turkmenistan
# ...

# %% [markdown]
# # Filtering / conditions

# %%
tb2.Person.head()
# Out:
# 0        Anna Andreadi
# 1          Chuck Magee
# 2       Kelly Williams
# 3    Cassandra Brandow
# Name: Person, dtype: object

# %%
tb2['Person'].head(2)
tb2[['Person','Sex']] #only 1 variable ie [[that,is]]
# Out:
#               Person Sex
# 0      Anna Andreadi   M
# 1        Chuck Magee   M
# 2     Kelly Williams   F
# 3  Cassandra Brandow   F

# %%
tb2[tb2.Sex=="M"]
# Out:
#           Person Region Sex  Age
# 0  Anna Andreadi   West   M   33
# 1    Chuck Magee   East   M   45

# %%
tb2[(tb2.Sex=="M") & (tb2.Region=="West")]
# Out:
#           Person Region Sex
# 0  Anna Andreadi   West   M

# %%
tb2[tb2.Region.isin(["West","Central"])]
# Out:
#            Person   Region Sex  Age
# 0   Anna Andreadi     West   M   33
# 2  Kelly Williams  Central   F   33

# %%
#tb2.drop(index=5, inplace=True) or tb = tb.drop(5, axis=0)                                                                      #Tb = Tb.drop(columns=['Av_price','profit']) or Tb = Tb.drop(['Av_price','profit'], axis= 1)
tb2.loc[len(tb2)]=["Killiams Lore","central", "F",33]
tb2
# Out:
#               Person   Region Sex   Age
# 0      Anna Andreadi     West   M  33.0
# 1        Chuck Magee     East   M  45.0
# 2     Kelly Williams  Central   F  33.0
# 3  Cassandra Brandow    South   F  55.0
# 4      Killiams Lore  central   F  33.0

# %%
tb2[tb2.Region.str.lower().isin(["west","central"])] #.str.lower() #"west","central"
# Out:
#            Person   Region Sex  Age
# 0   Anna Andreadi     West   M   33
# 2  Kelly Williams  Central   F   33
# 4   Killiams Lore  central   F   33

# %%
tb2[tb2.Person.str.contains('C')]
# Out:
#               Person Region Sex   Age
# 1        Chuck Magee   East   M  45.0
# 3  Cassandra Brandow  South   F  55.0

# %%
tb2[tb2.Region.str.contains('C') | tb2.Region.str.contains('c')]
# Out:
#            Person   Region Sex   Age
# 2  Kelly Williams  Central   F  33.0
# 4   Killiams Lore  central   F  33.0

# %%
tb2[tb2.Age<=30]
# Out:
# Empty DataFrame
# Columns: [Person, Region, Sex, Age]
# Index: []

# %%
tb2[(tb2.Sex=="M") | (tb2.Region=="Central")] #pipe function is OR
# Out:
#            Person   Region Sex   Age
# 0   Anna Andreadi     West   M  33.0
# 1     Chuck Magee     East   M  45.0
# 2  Kelly Williams  Central   F  33.0

# %%
tb2[(tb2.Region.isin(["West","Central"])) & (tb2.Sex=='F')]
# Out:
#            Person   Region Sex   Age
# 2  Kelly Williams  Central   F  33.0
